# %%
import pandas as pd

df = pd.read_excel(r'E:\Programing\PycharmProjects\2022MCM-B\Q1\MCMB数据[solve-regionB].xlsx')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.scatter(df['年'], df['牛放牧扩大占比'], df['犀牛栖息地百分比'], color='#9e2a22')

ax.set_xlabel('Year')
ax.set_ylabel('Cattle')
ax.set_zlabel('Rhino')

plt.tight_layout()
plt.savefig('Year-Rhino-Cattle.svg')
plt.show()
