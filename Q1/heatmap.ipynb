# %%
# 相关系数热力图

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False  #用来正常显示负号

data = pd.read_excel(r'E:\Programing\PycharmProjects\2022MCM-B\数据\相关系数测试.xlsx', sheet_name='区域1')
data.index = data.columns
data2 = pd.read_excel(r'E:\Programing\PycharmProjects\2022MCM-B\数据\相关系数测试.xlsx', sheet_name='区域2')
data2.index = data2.columns

# 画出热力图
fig1, ax1 = plt.subplots()
sns.set(font_scale=1.5)
sns.heatmap(data, vmax=1, vmin=-1, center=0, annot=True, ax=ax1, cmap=sns.light_palette("#f9b28c", as_cmap=True))
ax1.set_title('区域1 皮尔逊相关系数热力图')
plt.savefig('区域1 皮尔逊相关系数热力图.svg')
plt.show()

plt.rcParams['font.family'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False  #用来正常显示负号
fig2, ax2 = plt.subplots()
sns.set(font_scale=1.5)
sns.heatmap(data2, vmax=1, vmin=-1, center=0, annot=True, ax=ax2, cmap=sns.light_palette("#f9b28c", as_cmap=True))
ax2.set_title('区域2 皮尔逊相关系数热力图')
plt.savefig('区域2 皮尔逊相关系数热力图.svg')
plt.show()

# %%
data.columns
# Out:
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 37326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 29983 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 39135 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 33609 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 33268 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 32905 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 33829 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 32047 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20303 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 23487 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 29312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 29275 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26646 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 24687 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 30334 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25918 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 29287 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25193 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21344 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 37326 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 29983 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21160 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 39135 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 33609 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 33268 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20260 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20129 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 32905 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 33829 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 32047 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20303 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 23487 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 29312 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 29275 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 26646 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 24687 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 30334 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25918 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 29287 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 25193 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21344 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 37326 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 29983 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 21160 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 37327 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 39135 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 33609 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 33268 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 20260 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 20129 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 32905 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 33829 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 22320 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 32047 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 21644 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 20303 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 23487 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 29312 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 29275 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 26646 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 24687 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 30334 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 20998 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 27604 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 25918 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 29287 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 25193 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 21344 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 22495 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 30382 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 36874 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 30456 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 20851 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 31995 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\textpath.py:65: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22495 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 30382 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 36874 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 30456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20851 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 31995 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21306 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22495 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 30382 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 23572 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 36874 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 30456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 20851 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 31995 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 28909 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\th\.conda\envs\py310\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 22270 missing from current font.
#   font.set_text(s, 0, flags=flags)
