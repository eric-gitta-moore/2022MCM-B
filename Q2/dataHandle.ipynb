# %%
import numpy as np
import pandas as pd

df = pd.read_excel(r'E:\Programing\PycharmProjects\2022MCM-B\Q3\处理数据\政策(1).xlsx')
df
# Out:
#     政策  人口密度（人/平方千米）         耕地面积        森林面积  大象致人伤亡数量  食草动物致人伤亡数量  \
# 0    1      58.68055  107157.1500  25631.9500      3.80      0.9500
# 1    2      61.76900  101799.2925  25631.9500      3.80      0.9500
# 2    3      61.76900  107157.1500  24350.3525      3.80      0.9500
# 3    4      61.76900  107157.1500  25631.9500      3.61      0.9500
# 4    5      61.76900  107157.1500  25631.9500      3.80      0.9025
# 5    6      61.76900  107157.1500  25631.9500      3.80      0.9500
# 6    7      61.76900  107157.1500  25631.9500      3.80      0.9500
# 7    8      61.76900  107157.1500  25631.9500      3.80      0.9500
# 8    9      61.76900  107157.1500  25631.9500      3.80      0.9500
# 9   10      52.66620  101517.3000  24282.9000      3.60      0.9000
# 10  11      58.51800   91365.5700  24282.9000      3.60      0.9000
# 11  12      58.51800  101517.3000  21854.6100      3.60      0.9000
# 12  13      58.51800  101517.3000  24282.9000      3.24      0.9000
# ...
